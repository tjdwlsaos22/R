# %%
options(warn = -1)
options(repr.plot.width=15, repr.plot.height=9) 
Sys.setlocale(category = "LC_ALL", locale = "ko_KR.UTF-8")
# Out:
# [1] "ko_KR.UTF-8/ko_KR.UTF-8/ko_KR.UTF-8/C/ko_KR.UTF-8/C"

# %%
par(bg ='white')
x <- c(1,3,5,2,9,10)
plot(x,type='b',col='red',lwd=c(rep(3,3),rep(5,3)))
# Out:
# plot without title

# %%
#한 화면에 차트 여러개 그려서 비교하기.
par(bg='white')
price <- runif(10,1,100)
plot(price)
# Out:
# plot without title

# %%
#2행2열 차트 그리기
par(bg='white')
par(mfrow=c(2,2))
barplot(price,type='l')
plot(price,type='o')
plot(price,type='h')
plot(price,type='s')
# Out:
# plot without title

# %%
par(bg='white')
par(mfrow=c(2,2))
plot(price,type='o',pch=15)
plot(price,type='o',pch=15)
plot(price,type='o',pch=15)
plot(price,type='o',pch=c(rep(20,8),10),col='blue',cex=c(rep(1,8),3,1))
# Out:
# plot without title

# %% [markdown]
# ### 중첩자료 시각화

# %%
x <-c(1,2,3,4,2,4)
y <- rep(2,6)

# %%
par(bg='white')
plot(x,y)
# Out:
# plot without title

# %%
table(x,y)
par(bg='white')
xy.df <- as.data.frame(table(x,y))
xy.df
plot(x,y,pch=15,cex = xy.df$Freq) #커진것은 중복이라는 소리.
# Out:
#    y
# x   2
#   1 1
#   2 2
#   3 1
#   4 2
#   x y Freq
# 1 1 2 1
# 2 2 2 2
# 3 3 2 1
# 4 4 2 2
# plot without title

# %%
par(bg='white')
x <- c(1,1,1,2,2,2,2,2,2,3,3,4,5,6)
y <- c(1,1,4,2,3,2,2,2,3,2,1,1,1,1)
z <- data.frame(x,y)
sunflowerplot(z)

# iris의 sepal.length와 iris.sepeal.width의 중복 확인 산포도
sunflowerplot(iris$Sepal.Length,iris$Sepal.Width)
# Out:
# plot without title
# plot without title

# %% [markdown]
# ### chart 2개를 겹쳐서 출력하기

# %%
par(bg = 'white')
x <- 1:10
dotchart(x)

par(new =T) #현재차트 유지하고 다른차트를 그린다.

y <- c(1,2,1,4,5,2,7,7,2,5)
barplot(y,col='blue')
# Out:
# plot without title

# %% [markdown]
# ### 투명도

# %%
par(bg = 'white')
x <- 1:10
mycol <- rgb(0,0,1,seq(0,1,0.1))  #seq <- 컬러에 그라데이션 사용
dotchart(x,col='red')
par(new=T)
barplot(x,col=mycol)   #투명도하려면 색상은 무조건 rgb 4번째에 넣는게 투명도
# Out:
# plot without title

# %% [markdown]
# ### 상자 수염 그래프

# %%
par(bg='white')
abc <- c(110,300,150,280,310)
boxplot(abc,col='yellow',horizontal = T)
# Out:
# plot without title

# %%
summary(abc)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     110     150     280     230     300     310

# %%
jkl <- c(1,1,1,1,1,2,5)
summary(jkl)
par(bg = 'white')
boxplot(jkl)   #이상치를 확인하기 위한것. - 이상치 발견시 제거 후에 정렬을 해야한다.
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   1.000   1.000   1.000   1.714   1.500   5.000
# plot without title

# %%
par(bg = 'white' )
sunflowerplot(cars)
barplot(cars$dist)
boxplot(cars$dist)
# Out:
# plot without title
# plot without title
# plot without title

# %%
summary(cars$dist)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    2.00   26.00   36.00   42.98   56.00  120.00

# %%
dist_quantiles <- quantile(cars$dist)

cars$dist
# 최대값 제거
dist_quantiles <- cars$dist[-49]
dist_quantiles
summary(dist_quantiles)
par(bg='white')
boxplot(cars$dist)

#거리 바깥으로 가면 이상치 안이면 특이치
# Out:
#  [1]   2  10   4  22  16  10  18  26  34  17  28  14  20  24  28  26  34  34  46
# [20]  26  36  60  80  20  26  54  32  40  32  40  50  42  56  76  84  36  46  68
# [39]  32  48  52  56  64  66  54  70  92  93 120  85
#  [1]  2 10  4 22 16 10 18 26 34 17 28 14 20 24 28 26 34 34 46 26 36 60 80 20 26
# [26] 54 32 40 32 40 50 42 56 76 84 36 46 68 32 48 52 56 64 66 54 70 92 93 85
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    2.00   26.00   36.00   41.41   56.00   93.00
# plot without title

# %%
par(bg = 'yellow')
boxplot(iris$Sepal.Width,horizontal = T)
#원이 3개니까 1쪽은 박스길이보다 당연히 작으니 특이치. 그 다음 원2번째는 원1번째부터 더해서 계산 즉 특이치, 3번도 특이치
# Out:
# plot without title

# %%
par(family="AppleGothic",bg='white')
x<-c(1,3,6,8,9)
y<-c(12,56,78,32,9)

plot(x,y)
#(3,3)과 (4,4)를 연결하는 선분 그리기
segments(6,78, 8,32)

arrows(3,56,1,12,col='blue')

#사각형 그리기
rect(4,20,6,30,density = 30) ##사각형은 없는 위치로 만들수있음.
#글자쓰기
text(4,40,"This is a 샘플",srt=50)
#테두리
mtext("Character",side=4,adj=0.5)
# 그림의 테두리 그리기
box(lty=1,col='red')

# x축을 추가,y축의 40위치에 0~10까지 표시하고 빨간색
axis(1,pos = 40,at=0:10,col='red')
#y축 추가, x축의 6의 위치에 20~60
axis(2,pos=6,at=20:60,col='blue')
# Out:
# plot without title

# %%
library(dplyr)

election <- read.csv("./Data/election_2022.csv")
top4area1 <- arrange(election,desc(투표수))[1:5,2] ##시군구 이름만 나오ㅓㅁ.
top4area2 <- arrange(election,desc(투표수))[1:5,1] ##광역시도 이름만 나옴
#aggregate 안쓰는 이유는 시군구는 굳이 더할게없음. 그래서 시군구 앞에서 5개 광역시 5개해서 페이스트로 겹치는 것.

top4area3 <- paste(top4area2,top4area1)
top4area3

top41 <- c()
for(i in 1:length(top4area1)){
    topTemp1 <- apply(subset(election,광역시도 == top4area2[i] & 시군구 == top4area1[i])[,5:7],2,sum)
    top41 <- cbind(top41,topTemp1)
}
colnames(top41) <- top4area3

class(top41)  #matrix는 바 로 만들수있다. bind는 매트릭스 형태.


par(family = "AppleGothic", bg = 'lightgray')
options(scipen = 100)
barplot(top41,ylim = c(0,600000),legend.text = T)
head(election)
c <- arrange(election,desc(투표수))
c <- c[,5:7]
c <- head(c,5)
c$TotalVotes <- rowSums(c[, 1:3])
c$Lee <- round((c$`이재명`/c$TotalVotes)*100,2)
c$Yoon <- round((c$`윤석열`/c$TotalVotes)*100,2)
c$Sim <- round((c$`심상정`/c$TotalVotes)*100,2)
c

a <- arrange(election,desc(투표수))[,4]
a
l <- arrange(election,desc(투표수))[,5]
y <- arrange(election,desc(투표수))[,6]
s <- arrange(election,desc(투표수))[,7]
b <- head(a,5)
for (i in 1:length(c$Lee)) {
  text(0.7 + 1.2 * (i - 1), l[i]/2, paste0(round(c$Lee[i], 2), "%"))
  text(0.7 + 1.2 * (i - 1), l[i]+y[i]/2, paste0(round(c$Yoon[i], 2), "%"))
  text(0.7 + 1.2 * (i - 1), l[i]+y[i]+s[i]/2, paste0(round(c$Sim[i], 2), "%"))
}
# Out:
# [1] "경기도 화성시"     "경기도 부천시"     "경기도 남양주시"
# [4] "서울특별시 송파구" "서울특별시 강서구"
# [1] "matrix" "array"
#   광역시도   시군구   선거인수 투표수 이재명 윤석열 심상정
# 1 서울특별시 종로구   129968   100629  46130  49172 3115
# 2 서울특별시 중구     111448    84998  38244  42906 2310
# 3 서울특별시 용산구   199077   152068  60063  85047 4374
# 4 서울특별시 성동구   252087   197240  84411 103880 5365
# 5 서울특별시 광진구   303582   235471 109922 113733 7072
# 6 서울특별시 동대문구 300928   232106 108171 112890 6416
#   이재명 윤석열 심상정 TotalVotes Lee   Yoon  Sim
# 1 283324 236055 12955  532334     53.22 44.34 2.43
# 2 285227 224331 13249  522807     54.56 42.91 2.53
# 3 239179 203075 10089  452343     52.88 44.89 2.23
# 4 180490 255166 10652  446308     40.44 57.17 2.39
# 5 190000 181510 11100  382610     49.66 47.44 2.90
#   [1] 542027 532995 460518 453536 390247 368662 354778 349297 346084 340773
#  [11] 338768 335434 329653 328521 323033 317971 317197 316024 313203 304873
#  [21] 302170 301379 297278 296826 295658 295029 294832 292187 289459 285537
#  [31] 277878 272920 271510 264470 263581 260862 259616 256218 253347 253211
#  [41] 250764 250104 239154 238154 235471 235055 233474 232992 232106 231832
#  [51] 231447 231027 228238 226239 222254 220501 216629 216036 215995 210460
#  [61] 209589 208858 202633 199448 198669 197311 197240 197004 196600 193864
#  [71] 192948 192927 192412 189617 189310 189125 186646 183882 183089 183046
#  [81] 179768 177339 176406 173759 173557 170073 166298 163683 162812 162420
#  [91] 161006 157433 157035 155206 152184 152068 151200 148854 145891 145562
# [101] 145481 145187 143171 143063 142804 142368 141724 139351 138319 137512
# [111] 136658 135848 135108 127688 125233 124726 122198 120928 119627 119212
# [121] 118017 117836 117380 115404 113904 113105 112823 108990 106950 106148
# [131] 100876 100874 100629  98491  97962  95968  95575  90125  87091  84998
# [141]  84488  83065  81076  80080  75092  73877  73512  72566  71772  71696
# [151]  71492  70942  70769  70249  69786  68872  68459  65715  63481  62416
# [161]  61552  59326  58026  57532  57515  56509  54194  52516  51932  51349
# [171]  51325  49720  48473  48441  47171  46697  45152  43975  43642  42512
# [181]  42028  41791  41401  41399  40918  39245  39128  38707  37333  36856
# [191]  36321  35300  35136  34632  34327  34242  33699  33544  32625  32089
# [201]  32009  31795  31666  31270  30953  30297  29353  29323  29213  28904
# [211]  27992  27846  27419  27408  27048  27039  26955  26925  25897  24960
# [221]  24913  24898  23295  22717  22707  22653  22270  21836  21744  21588
# [231]  20717  20193  20057  19879  19716  19218  19132  19089  18855  18789
# [241]  18239  17429  16494  16230  14912  14529  12337   6653
# plot without title
